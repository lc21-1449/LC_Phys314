# %% [markdown]
# $\textbf{Activity 1:}$ Looking at some data types.  Look at the cell below.  Try changing x to various different things, e.g. \
# x = "Hello World!" \
# x = 2 \
# x = 5. \
# x = 3.1415 \
# x = 3.14 + 2.718j \
# x = True \
# x = [1, 2, 3, 4]

# %%
x =  "Class number 2"  # Change this to something else

print(x)        # Display x
print(type(x))  # Display the data type
# Out:
# 2
# <class 'int'>

# %% [markdown]
# \
# \
# $\textbf{Activity 2:}$ A string is sequence of characters.  We store "Hello World" in a.  Try changing the last line to print a[0], a[1], a[5], a[11].  What happens when you try to print a[12]?  Why?  What happens when you try to print a[-1]?  Try a[-2] and a[-3] also.

# %%
a = "Hello World!"

print(a)
print(list(a))   # Show what that list of characters in a looks like
print("The string length is ", len(a), "\n")

# Let's look at some of the individual elements of the sequence in a
print(a[0])  # <---- Change this line
# Out:
# Hello World!
# ['H', 'e', 'l', 'l', 'o', ' ', 'W', 'o', 'r', 'l', 'd', '!']
# The string length is  12
#
# H

# %% [markdown]
# \
# \
# $\textbf{Activity 3:}$ Slicing strings (i.e. making subsequences of characters).  Try looking at a[3:7], a[0:7], a[:7], a[7:], and a[1:10:3]

# %%
a = "Hello World!"

print(a[1:10:3])  # Slice the string
# Out:
# eoo
